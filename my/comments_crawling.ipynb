# %%
from bs4 import BeautifulSoup as bs
from urllib import request
import os
import re

# %%
# 현재 상영 중인 영화 목록을 알려주는 url을 바탕으로 bsObject 생성,
# 현재 상영 영화 목록을 담고 있는 ul태그를 movies에 담는다!
source_list = request.urlopen('https://movie.naver.com/movie/running/current.nhn?order=reserve')
soup= bs(source_list, 'html.parser')
movies = soup.find('ul', {'class':'lst_detail_t1'})

# %%
# 현재 상영 중인 영화들의 코드를 담아줄 list를 생성한다.
code_list = []

# 각 영화는 ul 태그 내(movies) li 태그로 열거되어 있으며,
# li 내부의 a태그를 통해 각 영화의 코드를 알아낼 수 있다!
for movie in movies.find_all('li'):
    movie_url = movie.a['href']    # ex) href="/movie/bi/mi/basic.nhn?code=132623"
    code = movie_url.split('=')[-1]
    # print(code)
    code_list.append(code)
# Out:
# 132623
# 180425
# 167651
# 182360
# 179974
# 177374
# 167099
# 182206
# 148909
# 171539
# 172145
# 172143
# 182407
# 167054
# 174830
# 181959
# 170953
# 181717
# 163008
# 183104
# 167616
# 109193
# 174730
# 158873
# 181711
# 178097
# 154288
# 179318
# 160837
# 170286
# 179033
# 179694
# 181554
# 167648
# 174832
# 175051
# 151151
# 144379
# 180992
# 168740
# 156464
# 70617
# 181409
# 167629
# 152694
# 168743
# 168050
# 159070
# 174297
# 182841
# 140110
# 178483
# 144318
# 147065
# 164335
# 49687
# 119552
# 171725
# 53047
# 152632
# 66598
# 167699
# 52991
# 153297
# 112082
# 168744
# 154983
# 179666
# 98446
# 98447
# 174329
# 149479
# 174296
# 162229
# 21931
# 169262
# 86958
# 154433
# 148647
# 155123
# 182032
# 181544

# %%
# single에서 써준 그대로 해주면 된다!
for code in code_list:
    # 우선 code만으로는 어떤 영화에서 작업하는지 모르기 때문에 title을 추출해낸다.
    source_title = request.urlopen(f'https://movie.naver.com/movie/bi/mi/basic.nhn?code={code}').read()
    soup = bs(source_title, 'html.parser')
    title = soup.find('h3', {'class':'h_movie'}).a.text
    
    # 혹시나 디렉터리 이름에 부적합한 기호가 있는 경우 지워준다!
    title = re.sub('[\/:*?"<>|]', '', title)
    print(f'working on {title}')
    
    # 총 몇 개의 (개봉 후) 평점이 있는지 알아본다!
    total = soup.find('div',{'class':'score_total'})
    # 개중에는 평점이 없는 경우도 있다
    # 이런 경우에는 그냥 다음 영화로!
    if total == None:
        print('no replies!')
        continue
    total = total.find_all('em')[-1].text
    total = total.strip()
    total = int(re.sub(',','',total))
    print(f'We have {total} replies!')
    
    # 총 페이지수를 가늠해보자!
    if int(total) % 10 == 0:
        pages = int(total) // 10
    else:
        pages = int(total) // 10 +1
    
    result_list = []
    
    for page in range(pages):
        # HTTPError: HTTP Error 502: Bad Gateway
        if (page + 1)%100 ==0:
            print(f'current : {page + 1} of {pages}')
        # sleep(0.01)
        home = f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code={code}&type=after&page={page+1}'
        source = request.urlopen(home).read()
        soup = bs(source, 'lxml')
        stars = soup.find_all('div', {'class':'star_score'})[1:]   # 처음에 사용자 입장에서 별점 주는 칸도 있어서 11개가 나옴!
        replies = soup.find_all('div', {'class':"score_reple"})
        for s, r in zip(stars, replies):
            reply = r.p.text
            if r.p.span:
                reply = reply[3:]
            result = f'{s.em.text}:{reply}\n'
            result_list.append(result)
        
    with open(f'./movies/{title}.txt', 'w', encoding = 'utf-8',) as f:
        f.writelines(set(result_list))    # set으로 하여 중복된 값 없애줌!
# Out:
# working on 극한직업
# We have 44112 replies!
# current : 100 of 4412
# current : 200 of 4412
# current : 300 of 4412
# current : 400 of 4412
# current : 500 of 4412
# current : 600 of 4412
# current : 700 of 4412
# current : 800 of 4412
# current : 900 of 4412
# current : 1000 of 4412
# current : 1100 of 4412
# current : 1200 of 4412
# current : 1300 of 4412
# current : 1400 of 4412
# current : 1500 of 4412
# current : 1600 of 4412
# current : 1700 of 4412
# current : 1800 of 4412
# current : 1900 of 4412
# current : 2000 of 4412
# current : 2100 of 4412
# current : 2200 of 4412
# current : 2300 of 4412
# current : 2400 of 4412
# current : 2500 of 4412
# current : 2600 of 4412
# current : 2700 of 4412
# current : 2800 of 4412
# current : 2900 of 4412
# current : 3000 of 4412
# current : 3100 of 4412
# current : 3200 of 4412
# current : 3300 of 4412
# current : 3400 of 4412
# current : 3500 of 4412
# current : 3600 of 4412
# current : 3700 of 4412
# current : 3800 of 4412
# current : 3900 of 4412
# current : 4000 of 4412
# current : 4100 of 4412
# current : 4200 of 4412
# current : 4300 of 4412
# current : 4400 of 4412
# working on 항거유관순 이야기
# We have 6275 replies!
# current : 100 of 628
# current : 200 of 628
# current : 300 of 628
# current : 400 of 628
# current : 500 of 628
# current : 600 of 628
# working on 라스트 미션
# We have 299 replies!
# working on 증인
# We have 9937 replies!
# current : 100 of 994
# current : 200 of 994
# current : 300 of 994
# current : 400 of 994
# current : 500 of 994
# current : 600 of 994
# current : 700 of 994
# current : 800 of 994
# current : 900 of 994
# working on 사바하
# We have 11622 replies!
# current : 100 of 1163
# current : 200 of 1163
# current : 300 of 1163
# current : 400 of 1163
# current : 500 of 1163
# current : 600 of 1163
# current : 700 of 1163
# current : 800 of 1163
# current : 900 of 1163
# current : 1000 of 1163
# current : 1100 of 1163
# working on 숲속왕국의 꿀벌 여왕
# We have 44 replies!
# working on 더 페이버릿 여왕의 여자
# We have 1440 replies!
# current : 100 of 144
# working on 그린 북
# We have 4416 replies!
# current : 100 of 442
# current : 200 of 442
# current : 300 of 442
# current : 400 of 442
# working on 아사코
# We have 158 replies!
# working on 철벽선생
# We have 95 replies!
# working on 1919 유관순
# We have 133 replies!
# working on 더 와이프
# We have 220 replies!
# working on 가버나움
# We have 2310 replies!
# current : 100 of 231
# current : 200 of 231
# working on 신데렐라마법 반지의 비밀
# We have 912 replies!
# working on 리노
# We have 59 replies!
# working on 칠곡 가시나들
# We have 310 replies!
# working on 살인마 잭의 집
# We have 340 replies!
# working on 킹 오브 프리즘 -샤이니 세븐 스타즈-
# We have 49 replies!
# working on 그때 그들
# We have 36 replies!
# working on 드래곤 길들이기 3
# We have 3549 replies!
# current : 100 of 355
# current : 200 of 355
# current : 300 of 355
# working on 에브리타임 룩 앳 유
# We have 17 replies!
# working on 나는 다른 언어로 꿈을 꾼다
# We have 32 replies!
# working on 러브 라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우
# We have 268 replies!
# working on 로마
# We have 1917 replies!
# current : 100 of 192
# working on 빠삐용
# We have 243 replies!
# working on 일일시호일
# We have 742 replies!
# working on 도쿄의 밤하늘은 항상 가장 짙은 블루
# We have 210 replies!
# working on 국경의 왕
# We have 49 replies!
# working on 슈퍼미니 2
# We have 94 replies!
# working on 인생 후르츠
# We have 1070 replies!
# current : 100 of 107
# working on 극장판 헬로카봇옴파로스 섬의 비밀
# We have 1986 replies!
# current : 100 of 199
# working on 질투의 역사
# We have 34 replies!
# working on 콜드 워
# We have 266 replies!
# working on 엔젤페이스
# We have 12 replies!
# working on 메리 포핀스 리턴즈
# We have 1429 replies!
# current : 100 of 143
# working on 러빙 빈센트
# We have 5601 replies!
# current : 100 of 561
# current : 200 of 561
# current : 300 of 561
# current : 400 of 561
# current : 500 of 561
# working on 브라더 오브 더 이어
# We have 53 replies!
# working on 히치하이크
# We have 11 replies!
# working on 보헤미안 랩소디
# We have 38565 replies!
# current : 100 of 3857
# current : 200 of 3857
# current : 300 of 3857
# current : 400 of 3857
# current : 500 of 3857
# current : 600 of 3857
# current : 700 of 3857
# current : 800 of 3857
# current : 900 of 3857
# current : 1000 of 3857
# current : 1100 of 3857
# current : 1200 of 3857
# current : 1300 of 3857
# current : 1400 of 3857
# current : 1500 of 3857
# current : 1600 of 3857
# current : 1700 of 3857
# current : 1800 of 3857
# current : 1900 of 3857
# current : 2000 of 3857
# current : 2100 of 3857
# current : 2200 of 3857
# current : 2300 of 3857
# current : 2400 of 3857
# current : 2500 of 3857
# current : 2600 of 3857
# current : 2700 of 3857
# current : 2800 of 3857
# current : 2900 of 3857
# current : 3000 of 3857
# current : 3100 of 3857
# current : 3200 of 3857
# current : 3300 of 3857
# current : 3400 of 3857
# current : 3500 of 3857
# current : 3600 of 3857
# current : 3700 of 3857
# current : 3800 of 3857
# working on 악질경찰
# We have 192 replies!
# working on 콜드 체이싱
# We have 677 replies!
# working on 어쩌다, 결혼
# We have 922 replies!
# working on 킬링 디어
# We have 659 replies!
# working on 이월
# We have 48 replies!
# working on 스타 이즈 본
# We have 6666 replies!
# current : 100 of 667
# current : 200 of 667
# current : 300 of 667
# current : 400 of 667
# current : 500 of 667
# current : 600 of 667
# working on 자전차왕 엄복동
# We have 6379 replies!
# current : 100 of 638
# current : 200 of 638
# current : 300 of 638
# current : 400 of 638
# current : 500 of 638
# current : 600 of 638
# working on 내가 사는 세상
# We have 33 replies!
# working on 봄은 온다
# We have 3 replies!
# working on 모험왕 블링키
# We have 36 replies!
# working on 시인 할매
# We have 128 replies!
# working on 언더독
# We have 1348 replies!
# current : 100 of 135
# working on 퍼미션
# We have 28 replies!
# working on 산상수훈
# We have 171 replies!
# working on 허비 행콕  무한한 가능성
# We have 20 replies!
# working on 포항
# We have 16 replies!
# working on 스파이더맨 뉴 유니버스
# We have 4953 replies!
# current : 100 of 496
# current : 200 of 496
# current : 300 of 496
# current : 400 of 496
# working on 송곳니
# We have 208 replies!
# working on 주먹왕 랄프 2 인터넷 속으로
# We have 4171 replies!
# current : 100 of 418
# current : 200 of 418
# current : 300 of 418
# current : 400 of 418
# working on 도화선
# We have 1434 replies!
# current : 100 of 144
# working on 말모이
# We have 13679 replies!
# current : 100 of 1368
# current : 200 of 1368
# current : 300 of 1368
# current : 400 of 1368
# current : 500 of 1368
# current : 600 of 1368
# current : 700 of 1368
# current : 800 of 1368
# current : 900 of 1368
# current : 1000 of 1368
# current : 1100 of 1368
# current : 1200 of 1368
# current : 1300 of 1368
# working on 안티크라이스트
# We have 393 replies!
# working on 1991, 봄
# We have 75 replies!
# working on 엽문3 최후의 대결
# We have 848 replies!
# working on 얼굴들
# We have 28 replies!
# working on 두 번째 겨울
# We have 29 replies!
# working on 마피아
# no replies!
# working on 님포매니악 볼륨1
# We have 453 replies!
# working on 님포매니악 볼륨2
# We have 380 replies!
# working on 다영씨
# We have 24 replies!
# working on 델타 보이즈
# We have 351 replies!
# working on 메이트
# We have 120 replies!
# working on 쇠파리
# We have 379 replies!
# working on 악인이여 지옥행 급행열차를 타라
# We have 12 replies!
# working on 페이트 스테이 나이트 헤븐즈필 제1장 프레시지 플라워
# We have 814 replies!
# working on 폭풍의 언덕
# We have 231 replies!
# working on 험악한 꿈
# We have 12 replies!
# working on 환절기
# We have 290 replies!
# working on 미스 사이공 25주년 특별 공연
# We have 234 replies!
# working on 어린 형수 4
# We have 3 replies!
# working on 초대녀 2
# We have 6 replies!

# %%
print('completed!')
# Out:
# completed!

# %% [markdown]
# Had to run several times b/c of http 502 bad gateway...

# %%
# now we're going to merge all the text files!
os.getcwd()
# Out:
# '/Users/jungwonchang/projects/web_crawling'

# %%
os.chdir('movies/')

# %%
all_text = []
for text in os.listdir():
    if '.txt' not in text:
        continue
    with open(text, 'r', encoding='utf-8') as f:
        replies = f.read()
        all_text.append(replies)

# %%
len(all_text)
# Out:
# 86

# %%
all_text[0]
# Out:
# '9:fill my all holes please  \n9:동이 틀 무렵 두 사람은 서로의 대화에 변화되었다  \n6:지루해서 보다가 뛰쳐나온 몇안되는 영화  \n8:너무나 매혹적인 몰입감을 준다. 유머와 조롱이 대단하며, 그 대상이 감독 스스로에게 향하는 것을 주저하지 않는다.  \n10:셀리그먼 아저씨 왜그러셨어요.. 감독의 메시지 전달을 위해 마지막 장면이 만들어진걸로 생각하고 싶다.  \n6:유쾌한상태로 남아있고싶다면 1편만 보시길  \n7:ㅋㅋㅋ... 만고의 진리 남자는다 똑같음  \n10:1편이 사색적이고 아름답다면 2편은 지극히 현실적이고 날카롭다.  볼륨 1을 보았던 관객이라면 2편의 분위기가 다소 낯설을수 있으나 시간이 흐르면 상반된 분위기에서 전률을 느낄수 있을것이다.  \n10:재밌는데...조가 \'난 색정증환자고, 이런 내가 좋아!\' 라고 말할때의 통쾌함!!  \n10:이야기가이어지나지루하지않은...  \n2:보고싶었는데.... 자느라 못 갔어요 취소도 못 해서 돈 날렸는데 자꾸 관람평 쓰라고 해서...  \n8:외로움과 위선 그리고 섹스의 사이에서  \n10:전형적인 정신 분석학에 따른 영화. 정말 멋지다  \n10:철컥철컥철컥철컥철컥쾅  \n8:마지막장면의 반전 및 여운  \n10:인간적인 영화 인간의 내면에 대해 다시 한번 생각하게 된 영화였음  \n8:예상밖의 익살스런 구석들이 매력적. 섹스중독에 관한 뻔한 유럽식 예술영화 정도일줄 알았는데. 책을 읽는 듯한 느낌을 주는 높은 몰입, 집중, 흡입력이 매우 좋은.  \n7:꿀잼꿀잼꿀잼꿀잼꿀잼  \n8:1편보다 완성도있지만 연출은 여전히 한국인인 내 정서에너무나도 과격함  \n9:적절한 지적유희와 함께 색정증여자의 이야기는 시간가는 줄 몰랐습니다~ 즐겁게 봤습니다!  